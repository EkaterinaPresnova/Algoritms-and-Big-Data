# %%
import pandas as pd

# %%
df = pd.read_csv('qm9.csv', sep=",")
df.head()
# Out:
#   mol_id smiles          A           B           C      mu  alpha    homo  \
# 0  gdb_1      C  157.71180  157.709970  157.706990  0.0000  13.21 -0.3877
# 1  gdb_2      N  293.60975  293.541110  191.393970  1.6256   9.46 -0.2570
# 2  gdb_3      O  799.58812  437.903860  282.945450  1.8511   6.31 -0.2928
# 3  gdb_4    C#C    0.00000   35.610036   35.610036  0.0000  16.28 -0.2845
# 4  gdb_5    C#N    0.00000   44.593883   44.593883  2.8937  12.99 -0.3604
#
#      lumo     gap       r2      zpve         u0       u298       h298  \
# 0  0.1171  0.5048  35.3641  0.044749 -40.478930 -40.476062 -40.475117
# 1  0.0829  0.3399  26.1563  0.034358 -56.525887 -56.523026 -56.522082
# 2  0.0687  0.3615  19.0002  0.021375 -76.404702 -76.401867 -76.400922
# 3  0.0506  0.3351  59.5248  0.026841 -77.308427 -77.305527 -77.304583
# 4  0.0191  0.3796  48.7476  0.016601 -93.411888 -93.409370 -93.408425
#
#         g298     cv
# 0 -40.498597  6.469
# 1 -56.544961  6.316
# 2 -76.422349  6.002
# ...

# %%
df.sample(n=20000, random_state=34)
# Out:
#             mol_id                 smiles        A        B        C      mu  \
# 65515    gdb_65516      CC1(OC2CC12)C1CN1  3.11349  1.43865  1.22003  1.7661
# 22428    gdb_22429       ON=C1CC2CC(C1)O2  3.64063  1.24925  1.10175  1.4225
# 22194    gdb_22195  C[NH2+]CC(CC#N)=N[O-]  1.98831  1.22992  0.84705  8.2679
# 110808  gdb_110809       COC1C2CC(C#C)C12  2.04220  1.82412  1.15961  1.1870
# 47118    gdb_47119       N=C1NC(=CCO1)C#C  3.30237  1.26351  0.93358  2.8254
# ...            ...                    ...      ...      ...      ...     ...
# 90785    gdb_90786        CC1OC2C3C1CC23O  3.91873  1.33889  1.22930  0.6101
# 61654    gdb_61655         CC(CC1COC1)C#C  4.04804  0.77994  0.69301  1.4398
# 124997  gdb_124998        Cc1c(c(no1)O)CO  2.12574  1.63393  0.96463  0.9577
# 50341    gdb_50342         O=CC1CC2CCC1O2  2.94435  1.47959  1.31805  2.0404
# 24710    gdb_24711        c1cc2c(nc1)COC2  3.76585  1.55344  1.11536  2.4484
#
# ...

# %%
df_sample = df.sample(n=20000, random_state=34)
df_sample.to_csv('/content/qm9_sample.csv', index=False)
